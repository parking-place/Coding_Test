# %% [markdown]
# # 광물캐기
# [문제 링크](https://school.programmers.co.kr/learn/courses/30/lessons/172927)

# %%
def solution(picks, minerals):
    answer = 0
    return answer

# %% [markdown]
# # 귤모으기

# %% [markdown]
# # 과제 진행하기

# %% [markdown]
# # 뒤에 있는 큰 수 찾기

# %% [markdown]
# # 다트게임
